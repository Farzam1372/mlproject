# %% [markdown]
# # Student Performance Indicator

# %% [markdown]
# Life cycle of machine learning projcet

# %% [markdown]
# - understanding the problem
# - Data Collection
# - Data chekcs to perform
# - Exploratory Data Analysis (EDA)
# - data pre-processing
# - Model training
# - Choose best model

# %% [markdown]
# ### 1) Problem statement

# %% [markdown]
# The idea is to understand how the student's performance (test score) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test prepartion course.

# %% [markdown]
# ### 2) Data Collection

# %% [markdown]
# - Data Soruce :  https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?datasetId=74977
# - The data consists of 8 column & 1000 rows.

# %% [markdown]
# ### 2.1 Import Data and required packages

# %% [markdown]
# Importing Pandas, Numpy, Matplotlib, seaborn and warning library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
